# %%
"""Answers for quiz2."""

# %%
 Как включить автосохранение данных в VSCODE\n",
2. Как настроить перенос строки? \n",
word wrap \n",
preferences - settings- wrap- wordaWrapColumn \n",
3. Сколько символов по pe разрешено на строке? \n",
79 \n",
4. Какие способы переноса строк показаны в видео: \n",
через settings \n",
с помощью + конкатинация \n",
5. Проверка на ошибки c помощью кнопки problems, где она находится? \n",
на панели рядом с terminal \n",
6. Где в vscode находится клиент гита? как в нём отправить коммит? как \n",принять  домашку? \n",
три кружочка, домашка принимается с помощью кнопки pull  \n",
7. Что такое GIT? он локальный? В нём можно посмотреть историю изменений \n",файлов и вернуться к любому коммиту?\n",
GitLines , Git- контроль версий, изменения - вкладка History
8. Как вставить картинку в маркдаун? \n",
Ctrl+V скриншот
9. Где посмотреть длину строки в vs code?\n",
10. Как поменять тип ячейки с питона на маркдаун?\n",
внизуn",
11. Как запустить сразу все ячейки в юпитере? \n",
RunAll \n",
12. Как изменить размер картинки в юпитере? Нужно для этого знать HTML?\n",
13. Какой хоткей чтобы запустить ячейку с смещением на следующую?\n",
Shift + Enter \n",
14. Как включить отображение номеров строк в юпитере(Cell line numbers)?\n",
Три точки - Show Cell line numbers \n",
15. Что такое "Go To" чем это полезно? Как перейти сразу на ошибочную ячейку?переброс на ошибочную ячейку\n",
16. Как очистить вывод ячеек которые уже запущены?\n",
нажать на кнопку Clear All Outputs \n",
17. Как работать одновременно в нескольких файлах в VSCODE? Что такое\n",
SPLIT? \n",
кн Split Edit - дублировать экран, работать в нескольких файлах, \n",
нескольких проектах \n",
18. Каким сочетанием убирается левый сайдбар?\n",
Ctrl+B
19. Кнопка два листочка это наши локальные файлы?\n",
yes \n",
20. Какая ошибка появилась в трассировке при запуске всех ячеек DICT или \n",liST\n",
21. Вы ознакомились с https://t.me/c/1937296927/832/19307? и ttps://github.com/\n",adam-p/markdown-here/wiki/Markdown-Cheatsheet?
да \n",
22. Что такое валидация?\n",
23. Что такое трассировка ошибки?\n",
24. Что значит отвалился интерпритатор?\n",
