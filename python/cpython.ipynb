# %%
"""interpretator Cpython и PYPY."""

# %% [markdown]
# ## Questions
#
# Введение в Python и CPython
#
# 1. Что такое CPython и чем он отличается от Python?
# ![differences_table](data:image/png;base64,...
# )
# 3. Сколько существует реализаций Python, и какая из них самая популярная?
# 4. На каком языке написан CPython?
#
# ### Поиск и установка CPython
#
# 5. (опционально) Кто создал CPython?
# 6. Почему Python считается быстрым, несмотря на то, что это интерпретируемый язык?
# 7. Напишите путь к Интерпретатору CPython на вашем компьютере
#
#
# ## Структура CPython
#
# 8. Что содержится в папке include в CPython?
# 9. Где можно найти исходный код CPython дайте ссылку на репозиторий гитхаб
# 10. (опционально) Как работает интерпретатор CPython при выполнении кода?
#
#
# ## Запуск файла с помощью CPython
#
# 11. Какая команда используется для запуска файла с помощью CPython?
# 12. Можно ли запускать текстовые файлы через интерпретатор Python? Почему?
# 13. Как указать путь к интерпретатору и файлу для выполнения кода?
#
#
# ## Введение в PyPy
#
# 14. Чем PyPy отличается от CPython?
# 15. Почему PyPy не может использоваться для всех проектов на Python?
# 16. Где можно скачать PyPy?
#
#
# ## Установка и запуск PyPy
#
# 17. Как установить PyPy после скачивания?
# 18. Как запустить файл с помощью PyPy?
# 19. Почему PyPy выполняет код быстрее, чем CPython?
#
# ## Практические задания
#
# ### Задание 1: Поиск и установка CPython
#
# Проверьте, установлен ли CPython на вашем компьютере:
#
#     Используйте поиск в меню "Пуск" (Windows) или терминале (Linux/Mac).
#     Введите команду python --version или python3 --version в терминале.
#
# Если CPython не установлен, скачайте его с официального сайта Python https://www.python.org/downloads/ и установите.
#
# ### Задание 2: Исследование структуры CPython
#
# Найдите папку, где установлен Python (например, через команду which python в терминале или свойства ярлыка).
# Откройте папку include и изучите её содержимое. Какое количество файлов на C там есть?
# Перейдите на [GitHub-репозиторий CPython](https://github.com/python/cpython) и найдите файл README. Прочитайте информацию о проекте.
#
# ### Задание 3: Запуск файла с помощью CPython
#
# Создайте текстовый файл example.txt с содержимым:
# print("Hello from CPython!")
#
# Запустите файл через команду python <путь_до_файла> (замените <путь_до_файла> на фактический путь к вашему файлу).
# Проверьте, что выводится на экран. Попробуйте изменить расширение файла на .py и повторите запуск.
#
# ### Задание 4: Установка и использование PyPy
#
# Перейдите на [официальный сайт PyPy](https://www.pypy.org/) и скачайте подходящую версию для вашей операционной системы.
# Распакуйте скачанный архив в удобное место.
# Создайте файл example_pypy.py с кодом:
# print("Hello from pypy!")
#
# Запустите файл через PyPy
# pypy <путь_до_файла> (замените <путь_до_файла> на фактический путь к вашему файлу).
# Проверьте, что выводится на экран. Попробуйте изменить расширение файла на .py и повторите запуск.
#
# ### Задание 5: Сравнение производительности CPython и PyPy
#
# Создайте файл performance_test.py с кодом:
#
#
#     ```
#     import time
#     start_time = time.time()
#     total = 0
#     for i in range(1, 10000000):
#         total += i
#     end_time = time.time()
#     print("Result:", total)
#     print("Execution time:", end_time - start_time, "seconds")
#     ```
#
# Запустите этот файл сначала через CPython, а затем через PyPy. Запишите результаты времени выполнения для обоих интерпретаторов.
# Сделайте вывод о разнице в производительности.

# %% [markdown]
# ## Answers
#
# 1. CPython is the default and most widely used implementation of Python, written in C. Python is a programming language, while CPython is a specific implementation that interprets Python code using C.
# 3.
#
# - *PyPy*
#
# The PyPy implementation is written in a restricted subset of Python called RPython. It often runs faster than CPython because it’s a just-in-time compiler instead of an interpreter.
#
# - *IronPython, Jython*
#
# IronPython is a Python implementation written in .NET, whereas Jython is implemented in Java. These variants are useful if you need to combine Python with existing .NET or Java code.
#
# - *Brython, Pyodide*
#
# Brython (Browser Python) is a rather exotic implementation that allows to run Python code directly in the browser by translating it into Javascript. Pyodide brings Python and various scientific libraries to the browser using WebAssembly.
#
# - *MicroPython, CircuitPython*
#
# MicroPython and CircuitPython are Python implementations optimized to run on microcontrollers.
#
# ### Search and CPython installation
#
# 5. Guido van Rossum
# 6.
# - Rich libraries – Pre-built modules.
# - C extensions – Speed-optimized libraries.
# - JIT (PyPy) – Faster execution.
# - Optimized CPython – Caching, memory management.
# 7. C:\Users\Maryia_Krauchanka\AppData\Local\Programs\Python\Python311
#
# ## CPython structure
#
# 8. Folder stores the c and python stuff (like writing modules in c and importing them in python)
# 9. https://github.com/python/cpython
# 10. CPython parses code-> compiles to bytecode -> executes on PVM(Python Virtual Machine).
#
# ## Code execution
#
# 11. python filename.py
# 12. yes, CPython doesn't validate extension as long it contains valid code
# 13. `/path/to/python /path/to/script.py`
#
#
# ## PyPy Intro
#
# 14. PyPy is an alternative implementation of Python with a Just-In-Time (JIT) compiler, making it faster for many workloads compared to CPython, which uses an interpreter. PyPy also provides better memory management.
# 15. C Extension Compatibility – Some libraries (e.g., NumPy, TensorFlow) rely on CPython’s C API and may not work well.
# 16. https://pypy.org/download.html
#
#
# ## Installation and run
#
# 17.
# - Extract the archive
# - Add it to PATH
#
# 18. `pypy my_script.py`
# 19. JIT Compilation that converts hot code into machine code at runtime.
#
#
# ## Practical assignment
#
# ### Task 1
#
# Done
#
# ### Task 2
#
# Done
#
# ### Task 3
#
# Done
#
# ### Task 4
#
# Done
#
# ### Task 5
#
#
# ```
# (SENATOROV) PS C:\learning\trainings\DS\Data-Science-For-Beginners-from-scratch-SENATOROV> python performance_test.py
# Result: 49999995000000
# Execution time: 0.6672496795654297 seconds
# (SENATOROV) PS C:\learning\trainings\DS\Data-Science-For-Beginners-from-scratch-SENATOROV> C:/programs/pypy/pypy3.11-v7.3.18-win64/pypy performance_test.py
# Result: 49999995000000
# Execution time: 0.01548457145690918 seconds
# ```
#
# PyPy is ~43 times faster than CPython in this test. The performance gain is due to PyPy's JIT compiler, which optimizes loops and reduces interpretation overhead
