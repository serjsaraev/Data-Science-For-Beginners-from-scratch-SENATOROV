# %%
"""Chapter."""

# %% [markdown]
# Introduction to Python

# %% [markdown]
# Python - это бесплатный интерпретируемый высокоуровневый язык программи­
# рования общего назначения с открытым исходным кодом

# %% [markdown]
# 2.2.7. Python Interpreters 1

# %% [markdown]
# По определению интерпретатор - это разновидность компьютерной программы,
# которая непосредственно выполняет инструкции, написанные на каком-либо языке

# %% [markdown]
# 2.2.8. Object orientation 1

# %% [markdown]
# Python поддерживает процедурно-ориентированное программирование, а также
# объектно-ориентированное программирование. В процедурно-ориентированных:
# языках программа состоит из процедур или функций, в которых заключены много-
