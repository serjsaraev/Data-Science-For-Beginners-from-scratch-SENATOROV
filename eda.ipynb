# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
"""Introduction to EDA."""
# Out:
# 'Introduction to EDA.'

# %% [markdown]
# EDA - это разведывательный анализ данных делается перед подготовкой модели\n",
# понижение размерности - задача проклятия размерности - основы линейной алгебры (мультиколлинеарность)\n",
# y- зависимая переменная, x- независимая\n",
# если взаимосвязь > 0.7 зависимые признаки нужно убрать\n",
# налоги и площадь - мультиколлинеарные призн, их коэф корреляции стремится к 1,\n",
#  один признак убираем, это и есть уменьшение размерности\n",
# Моделироване и оценка размерности чаще всего уменьш разм - метод главных компонентов\n",
# основы корреляц анализа, статистич, как в pandas\n",
# 1 -постановка задачи, выбрать правильной метрики для регрессии\n",
# описать данные \n",
# найти отличия\n",
# вывести взаимосвязи\n",
# Взаимосвязь данных - разные коэффиц корреляции количественные данные приводить к одному масштабу\n",
# или нормальному распределению. Эти фичи нужно в нормальный вид - фичинг инжениринг\n",
# категориальные данные закодировать в виде чисел\n",
# если категориальн данные выражены строками - препятствие маш обучению\n",
# Итеративный подход дя моделир признака\n",
# понижение размерности - задача проклятия размерности\n",
# В рамках EDA нам нужно решить три основные задачи: описать данные, найти\n",
# отличия и выявить взаимосвязи.\n",

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# функция read_csv() распознает zip-архивы,
# в архиве может содержаться только один файл
csv_zip = pd.read_csv('train.zip')
csv_zip.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %% [markdown]
# ![image.png](attachment:image.png)
