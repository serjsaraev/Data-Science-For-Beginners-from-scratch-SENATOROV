# %%
"""Venv."""

# %% [markdown]
# 1.  Что делает команда python -m venv venv?
#
# Создаёт виртуальное окружение в папке venv (= название виртуального
# окружения), чтобы при установке пакетов мы работали автономно,  не влияя на
# Python
#
# 1.1. Что делает каждая команда в списке ниже?
#
# ![398252421-62884319-9020-4c01-a4b2-2b956a34ecab.png](attachment:398252421-62884319-9020-4c01-a4b2-2b956a34ecab.png)
#
#     1) показывает названия пакетов и их версий, но не в формате, который
#     удобен для быстрой установки при работе с виртуальными окружениями
#
#     2) в файл requirements.txt сохраняются названия установленных пакетов и их
#     версии
#
#     3) устанавливаются все те пакеты, которые перечислены в файле
#     requirements.txt
#
# 2.  Что делает каждая команда в списке ниже?
#
# ![398252102-401cc261-1400-46a9-8b24-ae650d8ce859.png](attachment:398252102-401cc261-1400-46a9-8b24-ae650d8ce859.png)
#
#     1) Просмотр списка всех окружений conda
#
#     2) Создание виртуального окружения с именем env_name и версией Python 3.5
#
#     3) Обновление виртуального окружения env_name в соответствии с yml-файлом
#     file.yml
#
#     4) активация окружения env_name
#
#     5) деактивация активного окружения
#
#     6) очистка кэша пакетного менеджера conda
#
# 3.  вставьте скрин вашего терминала, где вы активировали сначала venv, потом
# conda, назовите окружение "SENATOROV"
#
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)
# ![image.png](attachment:image.png)
# ![image-4.png](attachment:image-4.png)
#
# 4.  Как установить необходимые пакеты внутрь виртуального окружения для
# conda/venv?
#
# conda/pip install <название_пакета>
#
# 5.  Что делают эти команды?
#
#     pip freeze > requirements.txt - сохраняют установленные пакеты и их
#     версии в формате, который затем можно быстро установить массово
#
#     conda env export > environment.yml - сохранение данных conda с
#     используемыми ресурсами и расположением для установки среды в yml-файл
#     environment.yml
#
# 5.1 вставьте скрин, где будет видна папка VENV в вашем репозитории а также
# файлы зависимостей requirements.txt и environment.yml, файлы должны содержать
# зависимости (у меня conda отрабатывает только в PyCharm, не в VSCode)
#
# ![image-7.png](attachment:image-7.png)
#
# 6.  Что делают эти команды?
#
#     pip install -r requirements.txt - устанавливаются пакеты из файла
#     requirements.txt в виртуальную среду
#
#     conda env create -f environment.yml - создание окружения с настройками
#     из yml-файла environment.yml, который содержит используемые ресурсы и
#     расположение для определения среды
#
# 7.  Что делают эти команды?
#
#     pip list - показывает названия пакетов и их версий, но не в формате,
#     который удобен для быстрой установки при работе с виртуальными окружениями
#
#     pip show <название_пакета> - показывает версию, описание, лицензию, автора
#     пакета и другую детальную инфо
#
#     conda list - показывает названия пакетов,и версий, канал и build для
#     conda-окружения
#
# 8.  Где по умолчанию больше пакетов venv/pip или conda? и почему дата
# сайнинисты используют conda?
#
#     pip — это менеджер пакетов для Python
#     venv — является менеджером среды для Python
#     conda — является одновременно менеджером пакетов и среды и не зависит от
#     языка
#
#     pip позволяет устанавливать сотни из тысяч пакетов из PyPi
#     conda обладает меньшим набором, но он содержит наиболее популярные пакеты
#
# Преимущества Conda включают: предоставление готовых пакетов, которые позволяют
# избежать необходимости иметь дело с компиляторами или выяснять, как настроить
# определенный инструмент. Также можно использовать pip в conda при
# необходимости добавить пакет необходимый.
#
# 9.  вставьте скрин где будет видно, Выбор интерпретатора Python (conda) в
# VS Code/cursor
#
# ![image-5.png](attachment:image-5.png)
#
# 10.  добавьте в .gitignore папку SENATOROV
#
# ![image-6.png](attachment:image-6.png)
#
# 11.  Зачем нужно виртуально окружение?
#
# Для автономной работы с необходимыми пакетами Python для различных проектов
# для избежания несовместимости версий пакетов
#
# 12.  С этого момента надо работать в виртуальном окружении conda, ты
# научился(-ась) выгружать зависимости и работать с окружением?
#
# =)
#
# 13.  Удалите папку VENV, она больше не нужна, мы же не разрабы, нам нужна
# только conda
#
# =)
