# %%
"""Занятие по математическому анализу."""

# %% [markdown]
# 02/02/2025
#
# Повторяли математический анализ (пределы, теория множеств)
#
# 1. К нулю может стремиться ФУНКЦИЯ, сам аргумент может стремиться только к +inf
# 2. Асцентрическая последовательность - когда в коридоре мы скачем от верхнего значения к нижнему
# 3. N(e), так как сначала выбираем "e", а потом N, поэтому N зависит от е
# 4. N - уникальный индекс
# 5. U - universum - содержит все множества или множество множеств
# 6. А\В - логическое вычетание
# 7. N+ = N U {0}
# 8. Ограниченная последовательность - ограничена несколькими одинаковыми элементами, например {2,2,2} {1,0,1,0}
# 9. Бесконечно-малая последовательность - элементы стремятся к нулю
# 10. При умножении бесконечно малой последовательности на ограниченную = бесконечно малая
# 11. Теория множеств: N - натуральные, N+ - натуральные+, Z - целые, Q - дробные, I - иррациональные (отдельно) {sqrt(2); pi; e; fi}, R - действительные (контейнер для всех множеств), С - комплексные
